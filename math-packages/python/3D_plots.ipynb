# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas
import seaborn as sns

# %%
fig = plt.figure()

ax = axes3d.Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
# Out:
# <Axes3D:>

# %%
i = np.arange(-1, 1, 0.01)
X, Y = np.meshgrid(i, i)
Z = X**2 - Y**2

# %%
ax.plot_wireframe(X, Y, Z, rcount = 10, ccount = 10)
fig

# %%
#fig, ax = plt.subplot((1, 3), figsize=(14, 4), subplot_kw=dict(projection='3d'))
fig, ax = plt.subplots(1, 3, figsize=(14, 4), subplot_kw=dict(projection='3d'))

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax[0].plot_surface(X, Y, Z, rstride=10, cstride=10, linewidth=0, antialiased = False, norm=norm, cmap='rainbow')

cb = fig.colorbar(p, ax=ax[0], shrink=0.6)

pp = ax[1].plot_wireframe(X, Y, Z, rstride=10, cstride=10,norm=norm, cmap=mpl.cm.jet)
#cbb = fig.colorbar(pp, ax=ax[1], shrink=0.6)
ppp = ax[2].plot_wireframe(X, Y, Z, rstride=10, cstride=10,norm=norm, cmap=mpl.cm.jet, antialiased = False,)
#cb = fig.colorbar(p, ax=ax[2], shrink=0.6)

# ax[2].contour()


fig

# %%
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j] # y , x
x = np.cos(u) * np.sin(v)
y = np.cos(u) * np.sin(v)
z = np.cos(v)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='rainbow')
